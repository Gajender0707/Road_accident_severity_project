# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("RTA Dataset.csv")

# %%
data.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
data.shape
# Out:
# (12316, 32)

# %%
data.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %%
data.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
data.head(1)
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver  Educational_level  \
# 0  17:02:00      Monday              18-30          Male  Above high school
#
#   Vehicle_driver_relation Driving_experience Type_of_vehicle Owner_of_vehicle  \
# 0                Employee              1-2yr      Automobile            Owner
#
#   Service_year_of_vehicle  ... Vehicle_movement Casualty_class  \
# 0              Above 10yr  ...   Going straight             na
#
#   Sex_of_casualty Age_band_of_casualty Casualty_severity Work_of_casuality  \
# 0              na                   na                na               NaN
#
#   Fitness_of_casuality Pedestrian_movement Cause_of_accident Accident_severity
# 0                  NaN    Not a Pedestrian   Moving Backward     Slight Injury
#
# [1 rows x 32 columns]

# %%
#as we can see that there are very need to be data cleaning first for doing anykind of operations

# %%
print(data.shape)
data=data.drop_duplicates()
data.shape
# Out:
# (12316, 32)
# (12316, 32)

# %%
## There is not dupliccay in the dataset

# %%
data.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
## lets explore first Target column
data["Accident_severity"].value_counts()
# Out:
# Accident_severity
# Slight Injury     10415
# Serious Injury     1743
# Fatal injury        158
# Name: count, dtype: int64

# %%
data["Time"]
# Out:
# 0        17:02:00
# 1        17:02:00
# 2        17:02:00
# 3         1:06:00
# 4         1:06:00
#            ...
# 12311    16:15:00
# 12312    18:00:00
# 12313    13:55:00
# 12314    13:55:00
# 12315    13:55:00
# Name: Time, Length: 12316, dtype: object

# %%
for i in data.columns:
    print(data[i].value_counts())
    print(">>>>"*30)
    print("<<<<<<"*30)
# Out:
# Time
# 15:30:00    120
# 17:10:00    110
# 18:30:00    103
# 11:30:00     99
# 17:00:00     98
#            ...
# 19:04:00      1
# 20:36:00      1
# 22:54:00      1
# 21:03:00      1
# 2:47:00       1
# Name: count, Length: 1074, dtype: int64
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Day_of_week
# Friday       2041
# Thursday     1851
# Wednesday    1840
# Tuesday      1770
# Monday       1681
# Saturday     1666
# Sunday       1467
# Name: count, dtype: int64
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ...

# %% [markdown]
# ### as by the Target column we can cleary see that this is the imbalance dataset so we need to more focus on fatal injury as compare to slight Injury

# %%
fatal_injury_data=data[data["Accident_severity"]=="Fatal injury"]

# %%
for i in fatal_injury_data.columns:
    print(fatal_injury_data[i].value_counts())
    print(">>>>"*30)
    print("<<<<<<"*30)
# Out:
# Time
# 21:15:00    12
# 11:16:00     6
# 17:10:00     6
# 18:00:00     5
# 0:10:00      5
#             ..
# 23:51:00     1
# 23:26:00     1
# 21:33:00     1
# 9:10:00      1
# 21:18:00     1
# Name: count, Length: 63, dtype: int64
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Day_of_week
# Saturday     37
# Sunday       35
# Thursday     22
# Wednesday    19
# Tuesday      17
# Friday       16
# Monday       12
# Name: count, dtype: int64
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ...

# %%
sns.countplot(fatal_injury_data["Age_band_of_casualty"],palette="Set2")
# Out:
# /var/folders/sn/kf4x3ygj0tg81pp8_fswhmp00000gn/T/ipykernel_28498/1360661491.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(fatal_injury_data["Age_band_of_casualty"],palette="Set2")
# <Axes: xlabel='count', ylabel='Age_band_of_casualty'>

# %%
sns.countplot(data=fatal_injury_data, x='Driving_experience', hue='Work_of_casuality', palette='coolwarm')
# Out:
# <Axes: xlabel='Driving_experience', ylabel='count'>

# %%
data.head(1)
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver  Educational_level  \
# 0  17:02:00      Monday              18-30          Male  Above high school
#
#   Vehicle_driver_relation Driving_experience Type_of_vehicle Owner_of_vehicle  \
# 0                Employee              1-2yr      Automobile            Owner
#
#   Service_year_of_vehicle  ... Vehicle_movement Casualty_class  \
# 0              Above 10yr  ...   Going straight             na
#
#   Sex_of_casualty Age_band_of_casualty Casualty_severity Work_of_casuality  \
# 0              na                   na                na               NaN
#
#   Fitness_of_casuality Pedestrian_movement Cause_of_accident Accident_severity
# 0                  NaN    Not a Pedestrian   Moving Backward     Slight Injury
#
# [1 rows x 32 columns]

# %%
sns.countplot(data,x="Accident_severity",hue="Age_band_of_casualty")
# Out:
# <Axes: xlabel='Accident_severity', ylabel='count'>

# %%
sns.countplot(data,x="Age_band_of_casualty",hue="Accident_severity")
# Out:
# <Axes: xlabel='Age_band_of_casualty', ylabel='count'>

# %%
data.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
#        'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
#        'Type_of_collision', 'Number_of_vehicles_involved',
#        'Number_of_casualties', 'Vehicle_movement', 'Casualty_class',
#        'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
#        'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %%
cat_features=[
    'Age_band_of_driver', 'Sex_of_driver',
       'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
       'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
       'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
       'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
       'Road_surface_conditions', 'Light_conditions', 'Weather_conditions'
]

# %%
data.head(1)
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver  Educational_level  \
# 0  17:02:00      Monday              18-30          Male  Above high school
#
#   Vehicle_driver_relation Driving_experience Type_of_vehicle Owner_of_vehicle  \
# 0                Employee              1-2yr      Automobile            Owner
#
#   Service_year_of_vehicle  ... Vehicle_movement Casualty_class  \
# 0              Above 10yr  ...   Going straight             na
#
#   Sex_of_casualty Age_band_of_casualty Casualty_severity Work_of_casuality  \
# 0              na                   na                na               NaN
#
#   Fitness_of_casuality Pedestrian_movement Cause_of_accident Accident_severity
# 0                  NaN    Not a Pedestrian   Moving Backward     Slight Injury
#
# [1 rows x 32 columns]

# %%
data.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
len(cat_features)
# Out:
# 17

# %%
fig,axes=plt.subplots(9,2,figsize=(30,30))
for i,feature in enumerate(cat_features):
    r,c=divmod(i,2)
    sns.countplot(x=data[feature],hue=data["Accident_severity"],ax=axes[r,c])

# %%
new_cat=cat_features[:6]
new_cat
# Out:
# ['Age_band_of_driver',
#  'Sex_of_driver',
#  'Educational_level',
#  'Vehicle_driver_relation',
#  'Driving_experience',
#  'Type_of_vehicle']

# %%
fig,axes=plt.subplots(3,2,figsize=(20,20))
for i,feature_name,in enumerate(new_cat):
    r,c=divmod(i,2)
    label=data[feature_name].value_counts().index
    val=data[feature_name].value_counts().values
    axes[r][c].pie(val,labels=label,autopct="%1.1f%%")
    axes[r][c].set_title(f"{feature_name.capitalize()} distribution")
